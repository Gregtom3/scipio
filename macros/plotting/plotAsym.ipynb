# %%
# %run ../../src/asym_plotter.ipynb

# %%
PROJECT_NAME="pipluspi0_noresonance_all"
MLmethod="catboost"

# %%
bin_dirs, outdir = get_dirs(PROJECT_NAME,MLmethod)
##################################################
for directory in [bin_dirs[0]]:
    for version in ['splot','sideband']:
        for datatype in ['nSidis','nSidis_Fall2018_inbending','nSidis_Fall2018_outbending','nSidis_Spring2019_inbending']:
            for ML in ['','noML']:
                # mkdir
                if(not os.path.exists(f"{outdir}/{datatype}/")):
                    os.mkdir(f"{outdir}/{datatype}")
                params = collect(directory,version,True,datatype,ML)
                make_azi_plots(params,version=version,outdir=(outdir+"/"+datatype),datatype=datatype,ML=ML)
# Out:
# nSidis_z_0.550000_0.620000
# nSidis_x_0.190000_0.235000
# nSidis_x_0.130000_0.160000
# nSidis_Mh_0.585714_0.728571
# nSidis_z_0.350000_0.430000
# nSidis_z_0.490000_0.550000
# nSidis_z_0.700000_0.800000
# nSidis_x_0.500000_1.000000
# nSidis_Mh_0.000000_0.300000
# nSidis_Mh_0.442857_0.585714
# nSidis_x_0.300000_0.500000
# nSidis_Mh_0.300000_0.442857
# nSidis_Mh_1.300000_2.000000
# nSidis_Mh_1.014286_1.157143
# nSidis_Mh_0.728571_0.871429
# nSidis_z_0.000000_0.350000
# nSidis_x_0.160000_0.190000
# nSidis_z_0.620000_0.700000
# nSidis_x_0.235000_0.300000
# nSidis_z_0.430000_0.490000
# nSidis_x_0.100000_0.130000
# nSidis_Mh_1.157143_1.300000
# nSidis_x_0.000000_0.100000
# nSidis_z_0.800000_1.000000
# nSidis_Mh_0.871429_1.014286
# nSidis_Mh_1.300000_2.000000_noML
# nSidis_z_0.490000_0.550000_noML
# nSidis_x_0.235000_0.300000_noML
# nSidis_Mh_1.157143_1.300000_noML
# nSidis_x_0.190000_0.235000_noML
# nSidis_z_0.350000_0.430000_noML
# nSidis_z_0.000000_0.350000_noML
# ...

# %%
# for d in [dir_1d]:#,dir_2d]:
#     for v in ['sideband','splot']:
#         for b in [False,True]:
#             params = collect(d,v,b)
#             make_mdiphoton_plots(params,b,v)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/macros/analysis/plots/mdiphoton_Mh_full_sideband.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/macros/analysis/plots/mdiphoton_x_full_sideband.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/macros/analysis/plots/mdiphoton_z_full_sideband.png has been created
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/macros/analysis/plots/mdiphoton_Mh_abbrev_sideband.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/macros/analysis/plots/mdiphoton_x_abbrev_sideband.png has been created
# ...

# %%
# %run ../../src/multiBin_plotter.ipynb

# %%
output_dir = "/work/clas12/users/gmat/scipio/macros/analysis/newplots"
plots_data = collect(dir_1d,False)
plots_MC   = collect(dir_mc_1d,False)
# Out:
# Reading TFile Mh_binned.root
# 	TTree 1 of 9
# 	TTree 2 of 9
# 	TTree 3 of 9
# 	TTree 4 of 9
# 	TTree 5 of 9
# 	TTree 6 of 9
# 	TTree 7 of 9
# 	TTree 8 of 9
# 	TTree 9 of 9
# Reading TFile x_binned.root
# 	TTree 1 of 8
# 	TTree 2 of 8
# 	TTree 3 of 8
# 	TTree 4 of 8
# 	TTree 5 of 8
# 	TTree 6 of 8
# 	TTree 7 of 8
# 	TTree 8 of 8
# Reading TFile z_binned.root
# 	TTree 1 of 8
# 	TTree 2 of 8
# 	TTree 3 of 8
# 	TTree 4 of 8
# 	TTree 5 of 8
# 	TTree 6 of 8
# 	TTree 7 of 8
# 	TTree 8 of 8
# Reading TFile z_binned.root
# 	TTree 1 of 8
# 	TTree 2 of 8
# 	TTree 3 of 8
# 	TTree 4 of 8
# 	TTree 5 of 8
# 	TTree 6 of 8
# 	TTree 7 of 8
# 	TTree 8 of 8
# Reading TFile x_binned.root
# 	TTree 1 of 8
# 	TTree 2 of 8
# 	TTree 3 of 8
# 	TTree 4 of 8
# 	TTree 5 of 8
# 	TTree 6 of 8
# 	TTree 7 of 8
# 	TTree 8 of 8
# Reading TFile Mh_binned.root
# 	TTree 1 of 9
# 	TTree 2 of 9
# 	TTree 3 of 9
# 	TTree 4 of 9
# 	TTree 5 of 9
# 	TTree 6 of 9
# 	TTree 7 of 9
# 	TTree 8 of 9
# 	TTree 9 of 9

# %%
make_binned_plots(plots_data,plots_MC,"Mgg",output_dir,False,True)
# Out:
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/macros/analysis/newplots/x_full_diff/Mgg.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/macros/analysis/newplots/z_full_diff/Mgg.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/macros/analysis/newplots/Mh_full_diff/Mgg.png has been created

# %%
c=ROOT.TCanvas()
#plots_data[2]["hists"][1]["Mgg"].GetYaxis().SetRangeUser(0,10000)
plots_MC[2]["hists"][0]["Mgg"].GetName()
#c.Draw()
# Out:
# 'Mgg_Mh_0.000000_0.300000_2022-12-29 12:52:54.538676'

# %%
output_dir = "/work/clas12/users/gmat/scipio/macros/analysis/newplots"
histnames = [key for key in pltfmt.keys()]
for b in [True,False]:
    for d,d_mc in zip([dir_1d,dir_2d],[dir_mc_1d,dir_mc_2d]):
        plots_data = collect(d,b)
        plots_MC   = collect(d_mc,b)
        for histname in histnames:
            make_binned_plots(plots_data,plots_MC,histname,output_dir,b,True)
# Out:
# Reading TFile Mh_binned.root
# 	TTree 1 of 9
# 	TTree 2 of 9
# 	TTree 3 of 9
# 	TTree 4 of 9
# 	TTree 5 of 9
# 	TTree 6 of 9
# 	TTree 7 of 9
# 	TTree 8 of 9
# 	TTree 9 of 9
# Reading TFile x_binned.root
# 	TTree 1 of 8
# 	TTree 2 of 8
# 	TTree 3 of 8
# 	TTree 4 of 8
# 	TTree 5 of 8
# 	TTree 6 of 8
# 	TTree 7 of 8
# 	TTree 8 of 8
# Reading TFile z_binned.root
# 	TTree 1 of 8
# 	TTree 2 of 8
# 	TTree 3 of 8
# 	TTree 4 of 8
# 	TTree 5 of 8
# 	TTree 6 of 8
# 	TTree 7 of 8
# 	TTree 8 of 8
# Reading TFile z_binned.root
# 	TTree 1 of 8
# 	TTree 2 of 8
# 	TTree 3 of 8
# 	TTree 4 of 8
# 	TTree 5 of 8
# 	TTree 6 of 8
# 	TTree 7 of 8
# 	TTree 8 of 8
# Reading TFile x_binned.root
# 	TTree 1 of 8
# 	TTree 2 of 8
# 	TTree 3 of 8
# 	TTree 4 of 8
# 	TTree 5 of 8
# 	TTree 6 of 8
# 	TTree 7 of 8
# 	TTree 8 of 8
# Reading TFile Mh_binned.root
# 	TTree 1 of 9
# 	TTree 2 of 9
# 	TTree 3 of 9
# 	TTree 4 of 9
# 	TTree 5 of 9
# 	TTree 6 of 9
# 	TTree 7 of 9
# 	TTree 8 of 9
# 	TTree 9 of 9
# ...

# %%
l=ROOT.TLegend()
l.SetBorderSize(0)

# %%
c=ROOT.TCanvas()
h=ROOT.TH1F()
h.Draw()
h.GetXaxis().SetNdivisions(510)
h.GetXaxis().SetLabelFont(42)
h.GetXaxis().SetTickSize(0.05)
axis = ROOT.TGaxis(0.2,0.2,0.8,0.2,0,1,510,"S")
axis.SetTickSize(0.06)

axis.Draw("same")
c.Draw()

# %%
c=ROOT.TCanvas()
plots_data[1]["hists"][0]["Mgg"].Draw()
c.Draw()

# %%
for idx_mc in range(len(plots_MC)):
    print(plots_MC[idx_mc]["name"]==["Mh"])
# Out:
# True
# False
# False

# %%
for idx_data in range(len(plots_data)):
    print(plots_data[idx_data]["name"])
# Out:
# ['x']
# ['Mh']
# ['z']
