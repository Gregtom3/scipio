# %%
# %run ../../src/multiBin_plotter.ipynb
# Out:
# Matplotlib created a temporary config/cache directory at /tmp/matplotlib-teynhse7 because the default path (/home/jovyan/.cache/matplotlib) is not a writable directory; it is highly recommended to set the MPLCONFIGDIR environment variable to a writable directory, in particular to speed up the import of Matplotlib and to better support multiprocessing.
# Welcome to JupyROOT 6.22/06

# %%
PROJECT_NAME="pipluspi0_noresonance"
MLmethod="catboost"

# %%
# Out:
# <module 'os' from '/opt/conda/lib/python3.8/os.py'>

# %%
bin_dirs, outdir = get_dirs(PROJECT_NAME,MLmethod)

histnames = [key for key in pltfmt.keys()]

DATATYPE=["all", "Fall2018_inbending", "Fall2018_outbending", "Spring2019_inbending"]
CUTDATA=["", "run>=5032 && run<=5332", "run>=5333 && run<=5666" , "run>=6616 && run<=6783"]
CUTMC=["","run==-11","run==11","run==-11"]
for b in [True,False]:
    for d in bin_dirs:
        for datatype,cutdata,cutmc in zip(DATATYPE,CUTDATA,CUTMC):
            plots_data = collect(input_dir = d,
                         skipEdges=b,
                         datatype="nSidis",
                         cut=cutdata)
            plots_MC = collect(input_dir = d,
                         skipEdges=b,
                         datatype="MC",
                         cut=cutmc)
            # mkdir
            if(not os.path.exists(f"{outdir}/{datatype}/")):
                    os.mkdir(f"{outdir}/{datatype}")
            for histname in histnames:
                for B in [False,True]: # False first, or else the dodiff histogram scaling will mess things up
                    make_binned_plots(params_data=plots_data,
                                      params_MC=plots_MC,
                                      histname=histname,
                                      outdir=outdir+"/"+datatype,
                                      skipEdges=b,
                                      dodiff=B)
# Out:
# Reading TFile nSidis_x_binned.root
# 	TTree 1 of 8
# 	TTree 2 of 8
# 	TTree 3 of 8
# 	TTree 4 of 8
# 	TTree 5 of 8
# 	TTree 6 of 8
# 	TTree 7 of 8
# 	TTree 8 of 8
# Reading TFile nSidis_z_binned.root
# 	TTree 1 of 8
# 	TTree 2 of 8
# 	TTree 3 of 8
# 	TTree 4 of 8
# 	TTree 5 of 8
# 	TTree 6 of 8
# 	TTree 7 of 8
# 	TTree 8 of 8
# Reading TFile nSidis_Mh_binned.root
# 	TTree 1 of 9
# 	TTree 2 of 9
# 	TTree 3 of 9
# 	TTree 4 of 9
# 	TTree 5 of 9
# 	TTree 6 of 9
# 	TTree 7 of 9
# 	TTree 8 of 9
# 	TTree 9 of 9
# Reading TFile MC_Mh_binned.root
# 	TTree 1 of 9
# 	TTree 2 of 9
# 	TTree 3 of 9
# 	TTree 4 of 9
# 	TTree 5 of 9
# 	TTree 6 of 9
# 	TTree 7 of 9
# 	TTree 8 of 9
# 	TTree 9 of 9
# Reading TFile MC_x_binned.root
# 	TTree 1 of 8
# 	TTree 2 of 8
# 	TTree 3 of 8
# 	TTree 4 of 8
# 	TTree 5 of 8
# 	TTree 6 of 8
# 	TTree 7 of 8
# 	TTree 8 of 8
# Reading TFile MC_z_binned.root
# 	TTree 1 of 8
# 	TTree 2 of 8
# 	TTree 3 of 8
# 	TTree 4 of 8
# 	TTree 5 of 8
# 	TTree 6 of 8
# 	TTree 7 of 8
# 	TTree 8 of 8
# Reading TFile nSidis_z_Mh_binned.root
# 	TTree 1 of 24
# 	TTree 2 of 24
# 	TTree 3 of 24
# 	TTree 4 of 24
# 	TTree 5 of 24
# 	TTree 6 of 24
# 	TTree 7 of 24
# 	TTree 8 of 24
# 	TTree 9 of 24
# 	TTree 10 of 24
# 	TTree 11 of 24
# 	TTree 12 of 24
# 	TTree 13 of 24
# 	TTree 14 of 24
# 	TTree 15 of 24
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-4b5370b68093> in <module>
#       5 for b in [True,False]:
#       6     for d in bin_dirs:
# ----> 7         plots_data = collect(input_dir = d,
#       8                      skipEdges=b,
#       9                      datatype="nSidis",
#
# <ipython-input-1-1467d14c92a8> in collect(input_dir, skipEdges, datatype, cut)
#      47                 h = ROOT.TH1F(f"{branch}_{treename}_{NOW}","",bins,low,high)
#      48                 h.Sumw2()
# ---> 49                 ttree.Draw(f"{branch}>>{branch}_{treename}_{NOW}",cut,"goff")
#      50                 h.SetDirectory(0)
#      51                 hists[branch]=h
#
# KeyboardInterrupt:
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/isGoodEventWithoutML.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/isGoodEventWithoutML.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/isGoodEventWithoutML.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/isGoodEventWithoutML.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/isGoodEventWithoutML.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/isGoodEventWithoutML.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/run.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/run.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Error in <TGaxis::PaintAxis>: wmin (0.000000) == wmax (0.000000)
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/run.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/run.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/run.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/run.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/fgID.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/fgID.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/fgID.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/fgID.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/fgID.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/fgID.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/x.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/x.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/x.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/x.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/x.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/x.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/Q2.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/Q2.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/Q2.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/Q2.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/Q2.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/Q2.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/Mx.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/Mx.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/Mx.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/Mx.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/Mx.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/Mx.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/z.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/z.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/z.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/z.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/z.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/z.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/hel.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/hel.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/hel.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/hel.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/hel.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/hel.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/Mgg.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/Mgg.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/Mgg.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/Mgg.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/Mgg.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/Mgg.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/Mh.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/Mh.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/Mh.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/Mh.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/Mh.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/Mh.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/phi_h.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/phi_h.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/phi_h.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/phi_h.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/phi_h.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/phi_h.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/phi_R0.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/phi_R0.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/phi_R0.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/phi_R0.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/phi_R0.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/phi_R0.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/phi_R1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/phi_R1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/phi_R1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/phi_R1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/phi_R1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/phi_R1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/th.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/th.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/th.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/th.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/th.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/th.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/prob_g1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/prob_g1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/prob_g1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/prob_g1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/prob_g1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/prob_g1.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev/prob_g2.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev/prob_g2.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev/prob_g2.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/x_abbrev_diff/prob_g2.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/Mh_abbrev_diff/prob_g2.png has been created
# Warning in <TCanvas::Constructor>: Deleting canvas with same name: c
# Info in <TCanvas::Print>: png file /work/clas12/users/gmat/scipio/projects/pipluspi0_noresonance_all/catboost/binnedPlots/z_abbrev_diff/prob_g2.png has been created

# %%
        plots_data = collect(input_dir = d,
                     skipEdges=b,
                     datatype="nSidis",
                     cut="")
        plots_MC = collect(input_dir = d,
                     skipEdges=b,
                     datatype="MC",
                     cut="")
# Out:
# Reading TFile nSidis_x_Mh_binned.root
# 	TTree 1 of 24
# 	TTree 2 of 24
# 	TTree 3 of 24
# 	TTree 4 of 24
# 	TTree 5 of 24
# 	TTree 6 of 24
# 	TTree 7 of 24
# 	TTree 8 of 24
# 	TTree 9 of 24
# 	TTree 10 of 24
# 	TTree 11 of 24
# 	TTree 12 of 24
# 	TTree 13 of 24
# 	TTree 14 of 24
# 	TTree 15 of 24
# 	TTree 16 of 24
# 	TTree 17 of 24
# 	TTree 18 of 24
# 	TTree 19 of 24
# 	TTree 20 of 24
# 	TTree 21 of 24
# 	TTree 22 of 24
# 	TTree 23 of 24
# 	TTree 24 of 24
# Reading TFile nSidis_z_Mh_binned.root
# 	TTree 1 of 24
# 	TTree 2 of 24
# 	TTree 3 of 24
# 	TTree 4 of 24
# 	TTree 5 of 24
# 	TTree 6 of 24
# 	TTree 7 of 24
# 	TTree 8 of 24
# 	TTree 9 of 24
# 	TTree 10 of 24
# 	TTree 11 of 24
# 	TTree 12 of 24
# 	TTree 13 of 24
# 	TTree 14 of 24
# 	TTree 15 of 24
# 	TTree 16 of 24
# 	TTree 17 of 24
# 	TTree 18 of 24
# 	TTree 19 of 24
# 	TTree 20 of 24
# 	TTree 21 of 24
# 	TTree 22 of 24
# 	TTree 23 of 24
# 	TTree 24 of 24
# Reading TFile MC_z_Mh_binned.root
# 	TTree 1 of 24
# 	TTree 2 of 24
# 	TTree 3 of 24
# 	TTree 4 of 24
# 	TTree 5 of 24
# 	TTree 6 of 24
# 	TTree 7 of 24
# 	TTree 8 of 24
# 	TTree 9 of 24
# 	TTree 10 of 24
# 	TTree 11 of 24
# 	TTree 12 of 24
# 	TTree 13 of 24
# 	TTree 14 of 24
# 	TTree 15 of 24
# 	TTree 16 of 24
# 	TTree 17 of 24
# 	TTree 18 of 24
# 	TTree 19 of 24
# 	TTree 20 of 24
# 	TTree 21 of 24
# 	TTree 22 of 24
# 	TTree 23 of 24
# 	TTree 24 of 24
# Reading TFile MC_x_Mh_binned.root
# 	TTree 1 of 24
# 	TTree 2 of 24
# 	TTree 3 of 24
# 	TTree 4 of 24
# 	TTree 5 of 24
# 	TTree 6 of 24
# 	TTree 7 of 24
# 	TTree 8 of 24
# 	TTree 9 of 24
# 	TTree 10 of 24
# 	TTree 11 of 24
# 	TTree 12 of 24
# 	TTree 13 of 24
# 	TTree 14 of 24
# 	TTree 15 of 24
# 	TTree 16 of 24
# 	TTree 17 of 24
# 	TTree 18 of 24
# 	TTree 19 of 24
# 	TTree 20 of 24
# 	TTree 21 of 24
# 	TTree 22 of 24
# 	TTree 23 of 24
# 	TTree 24 of 24
